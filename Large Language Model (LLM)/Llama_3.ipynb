# %%
# %%capture
import torch
major_version, minor_version = torch.cuda.get_device_capability()
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! Llama 3 is up to 8k
dtype = None
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

fourbit_models = [
    "unsloth/mistral-7b-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.2-bnb-4bit",
    "unsloth/llama-2-7b-bnb-4bit",
    "unsloth/gemma-7b-bnb-4bit",
    "unsloth/gemma-7b-it-bnb-4bit",
    "unsloth/gemma-2b-bnb-4bit",
    "unsloth/gemma-2b-it-bnb-4bit",

    "unsloth/llama-3-8b-bnb-4bit",
]

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/llama-3-8b-bnb-4bit", # Llama-3 70b also works (just change the model name)
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Llama patching release 2024.6
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/172 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
prompt = "Describe the tallest tower in the world"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
output = model.generate(input_ids)
print(tokenizer.decode(output[0], skip_special_tokens=True))

# 25 s
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Describe the tallest tower in the world
# The tallest tower in the world is the Shanghai Tower, which is 632 meters (2,073 feet) tall. It was completed in 2015. The tower is located in Shanghai, China. It is the third tallest building in the world, after the Burj Khalifa and the One World Trade Center.
# The Shanghai Tower is a mixed-use building that includes office space, hotels, and retail space. It is designed to be a sustainable building, with features such as a rainwater collection system and a green roof. The tower is also designed to withstand earthquakes.
# The Shanghai Tower is a major landmark in Shanghai. It is the tallest dans building in the world, and it is the tallest building in China. It is also the tallest building in the world that is not a skyscraper.
# The Shanghai Tower is a major tourist attraction in Shanghai. It is a popular destination for tourists from all over the world. The tower is also a major landmark in Shanghai, and it is a major tourist attraction.
# The Shanghai Tower is a major landmark in Shanghai, and it is a major tourist attraction. The tower is a major landmark in Shanghai, and it is a major tourist attraction. The Shanghai Tower is a major landmark in Shanghai, and it is a major tourist attraction. 感谢您阅读我的文章，希望能为您提供一些有用的信息。

# %%
prompt = "Describe the tallest tower in the Bangladesh"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
output = model.generate(input_ids)
print(tokenizer.decode(output[0], skip_special_tokens=True))

# 17 s
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Describe the tallest tower in the Bangladesh?
# The tallest tower in Bangladesh is the Jamuna Future Park Tower. It is located at Jamuna Future Park in Dhaka, Bangladesh. It is 120 meters tall. The Jamuna Future Park Tower isiffies a shopping mall, a hotel, and a parking garage. The tower has 23 floors.
# The Jamuna Future Park Tower is the tallest tower in Bangladesh. It is 120 meters tall and is located at Jamuna Future Park in Dhaka, Bangladesh. The tower has 23 floors and is used for a shopping mall, a hotel, and a parking garage.
# The tower was completed in 2012. The tower is located in Dhaka, the capital of Bangladesh. The tower is 120 meters tall and has 23 floors. The tower is used for a shopping mall, a hotel, and a parking garage.
# The Jamuna Future Park Tower is the tallest tower in Bangladesh. It is 120 meters tall and is located at Jamuna Future Park in Dhaka, Bangladesh. The tower has 23 floors and is used for a shopping mall, a hotel, and a parking garage. The tower was completed in 2012.

# %%
prompt = "Describe the tallest tower in the India"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
output = model.generate(input_ids)
print(tokenizer.decode(output[0], skip_special_tokens=True))

# 11 s
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Describe the tallest tower in the India.
# The tallest tower in India is the Qutub Minar. It is a minaret that forms part of the Qutub complex, located in Delhi. The tower is of 238 feet in height, and it was built by Qutub-ud-din Aibak, in 1193.
# The tallest tower in India is the Qutub Minar. It is a minaret that forms part of the Qutub complex, located in Delhi. The tower is of 238 feet in height, and it was built by Qutub_octin Aibak, in 1193.

# %%
prompt = "Top LLM model to generate text"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
output = model.generate(input_ids)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# 14
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Top LLM model to generate text given a prompt.
# This model is a fine-tuned version of OpenAI's GPT-2 model. It was trained on a large corpus of text, and has been fine-tuned to generate text given a prompt. The model is available as a REST API, and can be used to generate text given a prompt. The model is trained to generate text that is both grammatically correct and semantically coherent. It is not intended to be used for any malicious or illegal purposes.
# The model is trained to generate text that is both grammatically correct and semantically coherent. It is not intended to be used for any malicious or illegal purposes.
# The model is trained to generate text that is both grammatically correct and semantically coherent. It is not intended to be used for any malicious or illegal purposes.
# The model is trained to generate text that is both grammatically correct and semantically coherent. It is not intended to be used for any malicious or illegal purposes.

# %%
prompt = "Imagine you are a time traveler visiting the year 3000. Describe what you see"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
output = model.generate(input_ids)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# 14
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Imagine you are a time traveler visiting the year 3000. Describe what you see. What are the people like? What do they do? What do they eat? What do they wear? What are their houses like? What is their technology like? What do they think about the past? What do they think about the future? What do they think about you? What do you think about them?
# Write a story about a time traveler who visits the year 3000. Describe what you see. What are the people like? What do they do? What do they eat? What do they wear? What are their houses like? What is their technology like? What do they think about the past? What do they think about the future? What do they think about you? What do you think about them?
# Imagine you are a time traveler visiting the year 3000. Describe what you see. What are the people like? What do they do? What do they eat? What do they wear? What are their houses like? What is their technology like? What do they think about the past? What do they think about the future? What do they think about you? What do you think about them?

# %%
import time
# Start the timer
start = time.time()
# Example usage:
prompt = "Write me a poem about Machine Learning."
generated_story = generate_text(prompt)
print(generated_story)


# Print the time taken
print("\nTime:", time.time() - start)

# 52s        No quantization
# 16s        4 bit quantization
# Time: 8.663780927658081         4 bit quantization

# %%
# from transformers import TextStreamer
# from unsloth.chat_templates import get_chat_template
# tokenizer = get_chat_template(
#     tokenizer,
#     chat_template = "llama-3",
#     mapping = {"role" : "from", "content" : "value", "user" : "human", "assistant" : "gpt"}, # ShareGPT style
# )
# FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# %%
# messages = [
#     {"from": "human", "value": "Describe the tallest tower in the world."},
# ]
# inputs = tokenizer.apply_chat_template(messages, tokenize = True, add_generation_prompt = True, return_tensors = "pt").to("cuda")

# text_streamer = TextStreamer(tokenizer)
# _ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 1024, use_cache = True)
